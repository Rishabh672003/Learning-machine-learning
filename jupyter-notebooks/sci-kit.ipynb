# %%
# !wget https://lazyprogrammer.me/course_files/iris/iris.data
# !wget https://lazyprogrammer.me/course_files/iris/iris.names
# Out:
# --2023-12-22 10:50:29--  https://lazyprogrammer.me/course_files/iris/iris.data
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 104.21.23.210, 172.67.213.166, 2606:4700:3031::6815:17d2, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|104.21.23.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4551 (4.4K) [application/octet-stream]
# Saving to: ‘iris.data.2’
#
# iris.data.2         100%[===================>]   4.44K  --.-KB/s    in 0s
#
# 2023-12-22 10:50:30 (21.7 MB/s) - ‘iris.data.2’ saved [4551/4551]
#
# --2023-12-22 10:50:30--  https://lazyprogrammer.me/course_files/iris/iris.names
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 104.21.23.210, 172.67.213.166, 2606:4700:3031::6815:17d2, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|104.21.23.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2998 (2.9K) [application/octet-stream]
# Saving to: ‘iris.names.2’
#
# iris.names.2        100%[===================>]   2.93K  --.-KB/s    in 0s
#
# 2023-12-22 10:50:30 (43.4 MB/s) - ‘iris.names.2’ saved [2998/2998]

# %%
# !tail iris.names
# Out:
# 8. Missing Attribute Values: None
#
# Summary Statistics:
# 	         Min  Max   Mean    SD   Class Correlation
#    sepal length: 4.3  7.9   5.84  0.83    0.7826
#     sepal width: 2.0  4.4   3.05  0.43   -0.4194
#    petal length: 1.0  6.9   3.76  1.76    0.9490  (high!)
#     petal width: 0.1  2.5   1.20  0.76    0.9565  (high!)
#
# 9. Class Distribution: 33.3% for each of 3 classes.

# %%
import pandas as pd

# %%
df = pd.read_csv('iris.data', header=None)

# %%
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
X = df[[0,1,2,3]]
y = df[4]

# %%
X.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: 4, dtype: object

# %%
X.shape # N x D
# Out:
# (150, 4)

# %%
y.shape # N
# Out:
# (150,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
X_train.shape, y_train.shape
# Out:
# ((112, 4), (112,))

# %%
X_test.shape, y_test.shape
# Out:
# ((38, 4), (38,))

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=10000)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
model.score(X_train, y_train)
# Out:
# 0.9732142857142857

# %%
model.score(X_test, y_test)
# Out:
# 0.9736842105263158

# %%
X_more_test = [[6.3,3.1,6.1,0.3]]

# %%
model.predict(X_more_test)
# Out:
# array(['Iris-virginica'], dtype=object)
